# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthakkapila/Learning-AI/blob/main/WizardLM-13B-V1.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Running the Model**
#
# I have chosen the best open-source model (currently) and will use it for my project if, according to the performance if it performs poorly, I will fine tune the model.
# Even after fine-tunning if there isn't a significant performance, might just train my own model :P

# %%
# !pip install transformers torch numpy

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
model_name = "WizardLM/WizardLM-13B-V1.2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Input
text = "Hey! how are you doing?"
encoded_inputs = tokenizer(text, return_tensors="pt", padding="max_length", truncation=True)

# Generate
generate_ids = model.generate(encoded_inputs.input_ids, max_length=30)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/657 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/26.0G [00:00<?, ?B/s]
